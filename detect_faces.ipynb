# %%
from mtcnn import MTCNN
import cv2
import os

# datasets/test 폴더의 모든 이미지를 읽어서
# 그 결과를 datasets/test/detections 폴더에 텍스트로 저장하기

if not os.path.exists('datasets/test/detections'):
    os.makedirs('datasets/test/detections')

for filename in os.listdir('datasets/test'):
    if filename.endswith('.jpg'):
        img = cv2.cvtColor(cv2.imread('datasets/test/' + filename), cv2.COLOR_BGR2RGB)
        file_name_without_extension = os.path.splitext(filename)[0]
        with open('datasets/test/detections/' + file_name_without_extension + '.txt', 'w') as f:
            result = detector.detect_faces(img)
            if len(result) >= 0:
                first_result = result[0]
                keypoints = first_result["keypoints"]
                print(first_result)
                print(type(keypoints["left_eye"]))
                orders = ["left_eye", "right_eye", "nose", "mouth_left", "mouth_right"]
                for order in orders:
                    f.write(str(keypoints[order][0]) + '\t' + str(keypoints[order][1]) + '\n')
        print('Done:', filename)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# {'box': [138, 157, 267, 372], 'confidence': 0.9997182488441467, 'keypoints': {'left_eye': (208, 308), 'right_eye': (342, 306), 'nose': (279, 384), 'mouth_left': (233, 451), 'mouth_right': (323, 451)}}
# <class 'tuple'>
# Done: a.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# ...
